# %%
x=5
y=(2*x+5)/(x**2+5*x+6)
print("Result ",y)
# Out:
# Result  0.26785714285714285

# %%
x=5
y=(x**2+5*x+6)/(2*x+5)
print("Result ",y)
# Out:
# Result  3.7333333333333334

# %%
x=5
y=(2*x-3)*(x+9)
print("Result ",y)
# Out:
# Result  98

# %%
username=""
password=""
username_attempt=1
password_attempt=1
is_username_lock=False
is_password_lock=False

while username != "india":
    username=input("Enter Username :")
    if username_attempt >=3:
        username_attempt=+1
    else:   
        is_username_lock=True
    
while password != "ind":
    password=input("Enter Password :")
    if password_attempt >=3:
        password_attempt=+1
    else:   
        is_password_lock=True
print("Login Successfully !")
# Out:
# Enter Username :madhuri
# Enter Username :madhuri
# Enter Username :india
# Enter Password :mad
# Enter Password :ind
# Login Successfully !
